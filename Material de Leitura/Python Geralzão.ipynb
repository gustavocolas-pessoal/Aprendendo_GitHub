# %% [markdown]
# # APRENDENDO PYHTON

# %% [raw]
# Copiar link abaixo

# %% [raw]
# file:///C:/Users/gustavo2610049/Downloads/Aprendendo%20Python%20-%20um%20guia%20b%C3%A1sico%20de%20programa%C3%A7%C3%A3o.pdf
